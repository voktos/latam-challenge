# %% [markdown]
# # Challenge DE
# En este archivo puedes escribir lo que estimes conveniente. Te recomendamos detallar tu solución y todas las suposiciones que estás considerando. Aquí puedes ejecutar las funciones que definiste en los otros archivos de la carpeta src, medir el tiempo, memoria, etc.

# %% [markdown]
# Primero cargamos las extensiones para analizar el consumo de memoria y los tiempos de ejecucion de cada una de las funciones desarrolladas.

# %%
# %load_ext memory_profiler
# %load_ext line_profiler

# %% [markdown]
# Luego definimos el path donde tenemos almacenados los datos a procesar.

# %%
FILE_PATH = "../data/farmers-protest-tweets-2021-2-4.json"

# %% [markdown]
# ## Análisis de memoria
# Empecemos por importar las funciones que optimizan el bajo uso de memoria sobre el tiempo de ejecución.

# %%
from q1_memory import q1_memory
from q2_memory import q2_memory
from q3_memory import q3_memory

# %% [markdown]
# Analicemos línea por línea el uso de memoria para cada una de las funciones.

# %%
# %mprun -f q1_memory q1_mem_result = q1_memory(FILE_PATH)
# Out:
# Filename: /home/juaquin/Descargas/latam-challenge/src/q1_memory.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#     15     65.9 MiB     65.9 MiB           1   def q1_memory(file_path: str) -> List[Tuple[datetime.date, str]]:
#     16                                             """
#     17                                             Gets the top 10 dates with the most tweets and the user with the most
#     18                                             posts for each day while optimizing memory usage.
#     19
#     20                                             Args:
#     21                                                 file_path: The path to the input JSON file.
#     22
#     23                                             Returns:
#     24                                                 A list of tuples, where each tuple contains a date and its
#     25                                                     corresponding top user.
#     26                                             """
#     27     65.9 MiB      0.0 MiB           1       date_counts = {}
#     28     65.9 MiB      0.0 MiB           1       user_counts = {}
#     29     70.8 MiB      0.0 MiB           2       with open(file_path, encoding="utf-8") as json_file:
#     30     70.8 MiB      0.1 MiB      117408           for line in json_file:
#     31     70.8 MiB      3.2 MiB      117407               tweet = loads(line)
#     32     70.8 MiB      0.0 MiB      117407               tweet_date = tweet["date"][:10]
#     33     70.8 MiB      0.0 MiB      117407               tweet_username = tweet["user"]["username"]
#     34
#     35     70.8 MiB      0.0 MiB      117407               date_counts.setdefault(tweet_date, 0)
#     36     70.8 MiB      0.0 MiB      117407               user_counts.setdefault(tweet_date, {})
#     37     70.8 MiB      1.5 MiB      117407               user_counts[tweet_date].setdefault(tweet_username, 0)
#     38
#     39     70.8 MiB      0.0 MiB      117407               date_counts[tweet_date] += 1
#     40     70.8 MiB      0.0 MiB      117407               user_counts[tweet_date][tweet_username] += 1
#     41
#     42     70.8 MiB      0.0 MiB           1       top_10_counts = get_top_10(date_counts.values())
#     43     70.8 MiB      0.0 MiB          16       date_counts = {k: v for k, v in date_counts.items() if v in top_10_counts}
#     44
#     45     70.8 MiB      0.0 MiB          24       return [
#     46     70.8 MiB      0.0 MiB          10           (
#     47     70.8 MiB      0.0 MiB          10               datetime.strptime(tweet_date, "%Y-%m-%d").date(),
#     48     70.8 MiB      0.0 MiB          10               max(user_counts[tweet_date], key=user_counts[tweet_date].get),
#     49                                                 )
#     50     70.8 MiB      0.0 MiB          13           for tweet_date, _ in sorted(
#     51     70.8 MiB      0.0 MiB           1               date_counts.items(),
#     52     70.8 MiB      0.0 MiB          21               key=lambda x: x[1],
#     53     70.8 MiB      0.0 MiB           1               reverse=True,
#     54                                                 )[
#     55     70.8 MiB      0.0 MiB           1               :10
#     56                                                 ]  # This slice is here in case len(date_counts) > 10, wich can
#     57                                                 # happen if there are multiple dates with the same count and
#     58                                                 # that count is among the top 10 counts
#     59                                             ]

# %%
# %mprun -f q2_memory q2_mem_result = q2_memory(FILE_PATH)
# Out:
# Filename: /home/juaquin/Descargas/latam-challenge/src/q2_memory.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#     15     69.5 MiB     69.5 MiB           1   def q2_memory(file_path: str) -> List[Tuple[str, int]]:
#     16                                             """
#     17                                             Gets the top 10 most used emojis and its counts while optimizing memory
#     18                                             usage.
#     19
#     20                                             Args:
#     21                                                 file_path: The path to the input JSON file.
#     22
#     23                                             Returns:
#     24                                                 A list of tuples, where each tuple contains an emoji and its
#     25                                                     corresponding count.
#     26                                             """
#     27     69.5 MiB      0.0 MiB           1       emoji_counts = {}
#     28     69.5 MiB      0.0 MiB           2       with open(file_path, encoding="utf-8") as json_file:
#     29     69.5 MiB      0.0 MiB      117408           for line in json_file:
#     30     69.5 MiB      0.0 MiB      117407               line = loads(line)["content"]
#     31     69.5 MiB      0.0 MiB      161596               for emoji in findall(EMOJI_PATTERN, line):
#     32     69.5 MiB      0.0 MiB       44189                   emoji_counts.setdefault(emoji, 0)
#     33     69.5 MiB      0.0 MiB       44189                   emoji_counts[emoji] += 1
#     34
#     35     69.5 MiB      0.0 MiB           1       top_10_counts = get_top_10(emoji_counts.values())
#     36     69.5 MiB      0.0 MiB         591       emoji_counts = {
#     37     69.5 MiB      0.0 MiB         589           k: v for k, v in emoji_counts.items() if v in top_10_counts
#     38                                             }
#     39
#     40     69.5 MiB      0.0 MiB          21       return sorted(emoji_counts.items(), key=lambda x: x[1], reverse=True)

# %%
# %mprun -f q3_memory q3_mem_result = q3_memory(FILE_PATH)
# Out:
# Filename: /home/juaquin/Descargas/latam-challenge/src/q3_memory.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#     14     69.5 MiB     69.5 MiB           1   def q3_memory(file_path: str) -> List[Tuple[str, int]]:
#     15                                             """
#     16                                             Gets the top 10 most mentioned users and its counts while optimizing
#     17                                             memory usage.
#     18
#     19                                             Args:
#     20                                                 file_path: The path to the input JSON file.
#     21
#     22                                             Returns:
#     23                                                 A list of tuples, where each tuple contains a username and its
#     24                                                     corresponding count.
#     25                                             """
#     26     69.5 MiB      0.0 MiB           1       username_counts = {}
#     27
#     28     70.1 MiB      0.0 MiB           2       with open(file_path, encoding="utf-8") as json_file:
#     29     70.1 MiB      0.0 MiB      117408           for line in json_file:
#     30     70.1 MiB      0.0 MiB      117407               line = loads(line)
#     31     70.1 MiB      0.0 MiB      117407               if line["mentionedUsers"]:
#     32     70.1 MiB      0.0 MiB      141437                   for user in line["mentionedUsers"]:
#     33     70.1 MiB      0.6 MiB      103403                       username_counts.setdefault(user["username"], 0)
#     34     70.1 MiB      0.0 MiB      103403                       username_counts[user["username"]] += 1
#     35
#     36     70.1 MiB      0.0 MiB           1       top_10_counts = get_top_10(username_counts.values())
#     37     70.1 MiB      0.0 MiB       15243       username_counts = {
#     38     70.1 MiB      0.0 MiB       15241           k: v for k, v in username_counts.items() if v in top_10_counts
#     39                                             }
#     40
#     41     70.1 MiB      0.0 MiB          21       return sorted(username_counts.items(), key=lambda x: x[1], reverse=True)

# %% [markdown]
# Las tres funciones rondan los 70 MiB de uso de memoria. No se aprecia ningún incremento considerable línea por línea.
#
# Ahora comparémoslas con sus funciones contraparte, es decir, las que optimizan el tiempo de ejecución sobre el uso de memoria. En estos casos lo único que nos interesa es el uso máximo, así que no analizaremos línea por línea.

# %%
from q1_time import q1_time
from q2_time import q2_time
from q3_time import q3_time


# %memit q1_time_result = q1_time(FILE_PATH)
# %memit q2_time_result = q2_time(FILE_PATH)
# %memit q3_time_result = q3_time(FILE_PATH)
# Out:
# peak memory: 98.01 MiB, increment: 20.88 MiB
# peak memory: 80.74 MiB, increment: 0.00 MiB
# peak memory: 80.74 MiB, increment: 0.00 MiB

# %% [markdown]
# Hay un incremento en el uso de memoria de alrededor de 10 MiB para `q2` y `q3`, mientras que para `q1` es de más de 20 MiB. Esto seguramente se debe a que es la única función que utiliza `numpy`. Más adelante analizaremos la razón de esto.

# %% [markdown]
# ## Validación de resultados
# Antes de pasar al análisis de los tiempos de ejecución, primero validemos si, en efecto, sendas funciones coinciden en resultados.

# %%
print("q1", q1_mem_result == q1_time_result, q1_mem_result)
print("q2", q2_mem_result == q2_time_result, q2_mem_result)
print("q3", q3_mem_result == q3_time_result, q3_mem_result)
# Out:
# q1 True [(datetime.date(2021, 2, 12), 'RanbirS00614606'), (datetime.date(2021, 2, 13), 'MaanDee08215437'), (datetime.date(2021, 2, 17), 'RaaJVinderkaur'), (datetime.date(2021, 2, 16), 'jot__b'), (datetime.date(2021, 2, 14), 'rebelpacifist'), (datetime.date(2021, 2, 18), 'neetuanjle_nitu'), (datetime.date(2021, 2, 15), 'jot__b'), (datetime.date(2021, 2, 20), 'MangalJ23056160'), (datetime.date(2021, 2, 23), 'Surrypuria'), (datetime.date(2021, 2, 19), 'Preetm91')]
# q2 True [('🙏', 7286), ('😂', 3072), ('🚜', 2972), ('✊', 2411), ('🌾', 2363), ('🏻', 2080), ('❤', 1779), ('🤣', 1668), ('🏽', 1218), ('👇', 1108)]
# q3 True [('narendramodi', 2265), ('Kisanektamorcha', 1840), ('RakeshTikaitBKU', 1644), ('PMOIndia', 1427), ('RahulGandhi', 1146), ('GretaThunberg', 1048), ('RaviSinghKA', 1019), ('rihanna', 986), ('UNHumanRights', 962), ('meenaharris', 926)]

# %% [markdown]
# ### Consideraciones
# Efectivamente, las funciones están obteniendo los mismos resultados que sus respectivas contrapartes.
#
# Es importante mencionar algunas consideraciones que se tomaron en cuenta para llegar a estos resultados:
#
# - Para `q1`, la contabilización de tweets **no** toma en cuenta los campos `retweetedTweet` y `quotedTweet`.
# - Para `q2`, la contabilización de emojis **no** toma en cuenta el contenido de los campos `retweetedTweet` y `quotedTweet`.
# - Para `q2`, la contabilización de emojis toma en cuenta únicamente los caracters incluidos en la siguiente expresión regular:
#     ```python
#     EMOJI_PATTERN = (
#         r"[\U0001F300-\U0001F5FF" # Miscellaneous Symbols and Pictographs
#         r"\U0001F600-\U0001F64F"  # Emoticons
#         r"\U0001F680-\U0001F6FF"  # Transport and Map Symbols
#         r"\U0001F700-\U0001F77F"  # Alchemical Symbols
#         r"\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
#         r"\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
#         r"\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
#         r"\U0001FA00-\U0001FA6F"  # Chess Symbols
#         r"\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
#         r"\U00002702-\U000027B0"  # Dingbats
#         r"\U0001F004-\U0001F0CF]"  # Mahjong Tiles, Dominoes, Playing Cards
#     )
#     ```
# - Para `q3`, la contabilización de los usuarios más influyentes está en función de los usuarios que aparecen en los arreglos de los campos `mentionedUsers`.

# %% [markdown]
# ## Análisis de tiempo de ejecución
# Avancemos ahora con el análisis de los tiempos de ejecución.
#
# Comparemos el rendimiento de cada uno de los tres pares de funciones.

# %%
# %timeit q1_memory(FILE_PATH)
# %timeit q1_time(FILE_PATH)
# Out:
# 2.8 s ± 24.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 1.15 s ± 9.92 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit q2_memory(FILE_PATH)
# %timeit q2_time(FILE_PATH)
# Out:
# 3.06 s ± 17.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 1.38 s ± 19.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit q2_memory(FILE_PATH)
# %timeit q2_time(FILE_PATH)
# Out:
# 3.01 s ± 37 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 1.38 s ± 18.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# En los tres casos el tiempo de ejecución se reduce a menos de la mitad. Veamos el análisis línea por línea.

# %%
# %prun q1_time(FILE_PATH)
# Out:
#          452323 function calls in 1.291 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.615    0.615    1.290    1.290 q1_time.py:18(q1_time)
#    117407    0.508    0.000    0.508    0.000 {built-in method msgspec._core.json_decode}
#     49772    0.048    0.000    0.048    0.000 {built-in method _codecs.utf_8_decode}
#         1    0.035    0.035    0.035    0.035 {built-in method _collections._count_elements}
#         2    0.028    0.014    0.028    0.014 {built-in method numpy.array}
#     49772    0.025    0.000    0.073    0.000 <frozen codecs>:319(decode)
#    234834    0.015    0.000    0.015    0.000 {method 'append' of 'list' objects}
#        10    0.011    0.001    0.011    0.001 {method 'sort' of 'numpy.ndarray' objects}
#        10    0.002    0.000    0.014    0.001 _arraysetops_impl.py:339(_unique1d)
#         1    0.001    0.001    1.290    1.290 <string>:1(<module>)
#        10    0.000    0.000    0.000    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method io.open}
#        10    0.000    0.000    0.000    0.000 _strptime.py:309(_strptime)
#        10    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#        10    0.000    0.000    0.000    0.000 _function_base_impl.py:1369(diff)
#        10    0.000    0.000    0.014    0.001 _arraysetops_impl.py:145(unique)
#        20    0.000    0.000    0.000    0.000 fromnumeric.py:51(_wrapfunc)
#        10    0.000    0.000    0.001    0.000 _strptime.py:564(_strptime_datetime)
#        10    0.000    0.000    0.000    0.000 {method 'argmax' of 'numpy.ndarray' objects}
#        10    0.000    0.000    0.000    0.000 {method 'match' of 're.Pattern' objects}
#        10    0.000    0.000    0.000    0.000 locale.py:396(normalize)
#         1    0.000    0.000    0.000    0.000 __init__.py:610(most_common)
#         1    0.000    0.000    1.291    1.291 {built-in method builtins.exec}
#        10    0.000    0.000    0.000    0.000 {built-in method _locale.setlocale}
#         1    0.000    0.000    0.000    0.000 heapq.py:523(nlargest)
#        10    0.000    0.000    0.001    0.000 {built-in method strptime}
#        10    0.000    0.000    0.000    0.000 fromnumeric.py:1251(argmax)
#        10    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#        10    0.000    0.000    0.000    0.000 locale.py:594(getlocale)
#        10    0.000    0.000    0.000    0.000 _strptime.py:26(_getlang)
#        10    0.000    0.000    0.000    0.000 locale.py:479(_parse_localename)
#        30    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#        10    0.000    0.000    0.000    0.000 fromnumeric.py:2018(nonzero)
#        10    0.000    0.000    0.000    0.000 {method 'groupdict' of 're.Match' objects}
#         1    0.000    0.000    0.035    0.035 __init__.py:587(__init__)
#         1    0.000    0.000    0.035    0.035 __init__.py:660(update)
#        41    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#         1    0.000    0.000    0.000    0.000 heapq.py:565(<listcomp>)
#        21    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        10    0.000    0.000    0.000    0.000 _arraysetops_impl.py:132(_unpack_tuple)
#         1    0.000    0.000    0.000    0.000 <frozen abc>:117(__instancecheck__)
#        10    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#        30    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
#        10    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#        10    0.000    0.000    0.000    0.000 {built-in method numpy.lib.array_utils.normalize_axis_index}
#        10    0.000    0.000    0.000    0.000 _arraysetops_impl.py:140(_unique_dispatcher)
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:260(__init__)
#        20    0.000    0.000    0.000    0.000 {method 'toordinal' of 'datetime.date' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:309(__init__)
#        10    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#        10    0.000    0.000    0.000    0.000 _function_base_impl.py:1365(_diff_dispatcher)
#        10    0.000    0.000    0.000    0.000 {method 'weekday' of 'datetime.date' objects}
#         1    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#        10    0.000    0.000    0.000    0.000 fromnumeric.py:2014(_nonzero_dispatcher)
#        10    0.000    0.000    0.000    0.000 {method 'end' of 're.Match' objects}
#        10    0.000    0.000    0.000    0.000 {method 'date' of 'datetime.datetime' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _heapq.heapify}
#         1    0.000    0.000    0.000    0.000 heapq.py:579(<listcomp>)
#        10    0.000    0.000    0.000    0.000 multiarray.py:180(concatenate)
#        10    0.000    0.000    0.000    0.000 fromnumeric.py:1247(_argmax_dispatcher)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         1    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method _heapq.heapreplace}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
# %prun q2_time(FILE_PATH)
# Out:
#          921421 function calls in 1.676 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.618    0.618    1.676    1.676 q2_time.py:18(q2_time)
#    117407    0.515    0.000    0.515    0.000 {built-in method msgspec._core.json_decode}
#    117407    0.299    0.000    0.299    0.000 {method 'findall' of 're.Pattern' objects}
#    117408    0.052    0.000    0.164    0.000 __init__.py:660(update)
#     49772    0.049    0.000    0.049    0.000 {built-in method _codecs.utf_8_decode}
#    117408    0.042    0.000    0.087    0.000 {built-in method builtins.isinstance}
#     49772    0.030    0.000    0.079    0.000 <frozen codecs>:319(decode)
#    117407    0.025    0.000    0.025    0.000 {built-in method _collections._count_elements}
#    117407    0.022    0.000    0.045    0.000 <frozen abc>:117(__instancecheck__)
#    117407    0.022    0.000    0.022    0.000 {built-in method _abc._abc_instancecheck}
#         1    0.001    0.001    0.001    0.001 {built-in method io.open}
#         1    0.000    0.000    0.000    0.000 heapq.py:523(nlargest)
#         1    0.000    0.000    1.676    1.676 {built-in method builtins.exec}
#         1    0.000    0.000    1.676    1.676 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#         1    0.000    0.000    0.000    0.000 __init__.py:610(most_common)
#         1    0.000    0.000    0.000    0.000 heapq.py:565(<listcomp>)
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:309(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:272(_compile)
#         1    0.000    0.000    0.000    0.000 __init__.py:587(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _heapq.heapify}
#         6    0.000    0.000    0.000    0.000 {built-in method _heapq.heapreplace}
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:260(__init__)
#         1    0.000    0.000    0.000    0.000 heapq.py:579(<listcomp>)
#         1    0.000    0.000    0.000    0.000 __init__.py:225(compile)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}

# %%
# %prun q3_time(FILE_PATH)
# Out:
#          232229 function calls in 1.190 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.609    0.609    1.190    1.190 q3_time.py:16(q3_time)
#    117407    0.502    0.000    0.502    0.000 {built-in method msgspec._core.json_decode}
#     49772    0.048    0.000    0.048    0.000 {built-in method _codecs.utf_8_decode}
#     49772    0.027    0.000    0.075    0.000 <frozen codecs>:319(decode)
#         1    0.002    0.002    0.002    0.002 heapq.py:523(nlargest)
#     15239    0.001    0.000    0.001    0.000 __init__.py:601(__missing__)
#         1    0.001    0.001    0.001    0.001 {built-in method io.open}
#         1    0.000    0.000    1.190    1.190 <string>:1(<module>)
#         1    0.000    0.000    0.002    0.002 __init__.py:610(most_common)
#         1    0.000    0.000    1.190    1.190 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#         1    0.000    0.000    0.000    0.000 heapq.py:565(<listcomp>)
#        20    0.000    0.000    0.000    0.000 {built-in method _heapq.heapreplace}
#         1    0.000    0.000    0.000    0.000 __init__.py:587(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:309(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 heapq.py:579(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {built-in method _heapq.heapify}
#         1    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 __init__.py:660(update)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:260(__init__)

# %% [markdown]
# Entonces, en los tres casos, poco menos de la mitad del tiempo de ejecución lo acapara `msgspec` al momento de decodificar las líneas del archivo JSON. Esto podría considerarse un cuello de botella, aunque en realidad `msgspec` es una herramienta bastante rápida para leer archivos JSON. Hagamos una comparación sencilla con el tiempo que le tomaría a la librería estándar `json`.

# %%
from json import loads

from msgspec.json import decode

from schemas import Tweet


def read_json(file_path: str):
    with open(file_path, encoding="utf-8") as json_file:
        for line in json_file:
            _ = loads(line)


def read_json_with_schema(file_path: str):
    with open(file_path, encoding="utf-8") as json_file:
        for line in json_file:
            _ = decode(line, type=Tweet)

# %%
# %prun read_json(FILE_PATH)
# Out:
#          1273623 function calls in 3.165 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    117407    1.982    0.000    1.982    0.000 decoder.py:343(raw_decode)
#         1    0.705    0.705    3.165    3.165 1208675.py:8(read_json)
#    117407    0.152    0.000    2.243    0.000 decoder.py:332(decode)
#    117407    0.097    0.000    2.374    0.000 __init__.py:299(loads)
#    234814    0.077    0.000    0.077    0.000 {method 'match' of 're.Pattern' objects}
#     49772    0.053    0.000    0.053    0.000 {built-in method _codecs.utf_8_decode}
#     49772    0.032    0.000    0.085    0.000 <frozen codecs>:319(decode)
#    117407    0.023    0.000    0.023    0.000 {method 'startswith' of 'str' objects}
#    234814    0.020    0.000    0.020    0.000 {method 'end' of 're.Match' objects}
#    117407    0.012    0.000    0.012    0.000 {built-in method builtins.len}
#    117407    0.012    0.000    0.012    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.000    0.000 {built-in method io.open}
#         1    0.000    0.000    3.165    3.165 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#         1    0.000    0.000    3.165    3.165 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 interactiveshell.py:316(_modified_open)
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:309(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:260(__init__)

# %%
# %prun read_json_with_schema(FILE_PATH)
# Out:
#          216960 function calls in 1.099 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.534    0.534    1.098    1.098 1208675.py:14(read_json_with_schema)
#    117407    0.492    0.000    0.492    0.000 {built-in method msgspec._core.json_decode}
#     49772    0.047    0.000    0.047    0.000 {built-in method _codecs.utf_8_decode}
#     49772    0.026    0.000    0.072    0.000 <frozen codecs>:319(decode)
#         1    0.000    0.000    0.000    0.000 {built-in method io.open}
#         1    0.000    0.000    1.099    1.099 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#         1    0.000    0.000    1.098    1.098 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:309(__init__)
#         1    0.000    0.000    0.000    0.000 interactiveshell.py:316(_modified_open)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:260(__init__)

# %% [markdown]
# `msgspec` es tres veces más rápido que la librería estándar, al menos en el caso específico de nuestro archivo JSON.

# %% [markdown]
# ## Soluciones alternativas
# Por supuesto, hay otras formas de parsear datos que también pueden ser eficientes, tanto en tiempo de ejecución como en uso de memoria. Podemos, por ejemplo, usar `pandas`. Sin embargo, las soluciones aquí presentadas están pensadas específicamente para procesar nuestro archivo JSON, cuyos datos son semiestructurados, mientras que `pandas` es óptimo para trabajar con datos estructurados.
#
# En este *challenge* no se usó `pandas` porque el sólo hecho de leer el archivo con `pd.read_json` causaba un incremento considerable tanto en uso de memoria como en tiempo de ejecución. Ahora bien, esto no significa que `pandas` no sea eficiente en cuanto a uso de memoria/tiempo de ejecución, sino que esto dependerá del volumen de datos y la estructura que estos tengan (si son estructurados o no, y si no, qué tan complejos o cuántos niveles de profundidad tienen).
#
# Hagamos una prueba rápida tomando como ejemplo `q1` y codifiquemos su equivalente en `pandas`

# %%
from datetime import datetime
from typing import List, Tuple

import pandas as pd


def q1_pandas(file_path: str) -> List[Tuple[datetime.date, str]]:
    """
    Gets the top 10 dates with the most tweets and the user with the most
    posts for each day while using pandas.

    Args:
        file_path: The path to the input JSON file.

    Returns:
        A list of tuples, where each tuple contains a date and its
            corresponding top user.
    """
    chunk_list = []
    chunksize = 10000
    for chunk in pd.read_json(file_path, lines=True, chunksize=chunksize):
        chunk["date"] = pd.to_datetime(chunk["date"]).dt.date
        chunk["username"] = chunk["user"].apply(lambda x: x["username"])
        chunk_list.append(chunk)

    df = pd.concat(chunk_list, ignore_index=True)
    df_grouped = df.groupby(["date", "username"]).size().reset_index(name='count')
    top_10_dates = df.groupby('date').size().nlargest(10).index

    results = []
    for date in top_10_dates:
        date_group = df_grouped[df_grouped['date'] == date]
        top_user = date_group.loc[date_group['count'].idxmax()]
        results.append((date, top_user['username']))

    return results

# %%
# %prun q1_pandas_result = q1_pandas(FILE_PATH)
# Out:
#          948800 function calls (943186 primitive calls) in 9.151 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        12    4.448    0.371    4.500    0.375 {built-in method pandas._libs.json.ujson_loads}
#      6012    0.782    0.000    0.785    0.000 datetimes.py:645(__iter__)
#         1    0.613    0.613    9.151    9.151 <string>:1(<module>)
#        13    0.539    0.041    7.375    0.567 _json.py:1085(__next__)
#        12    0.283    0.024    0.435    0.036 construction.py:891(_list_of_dict_to_arrays)
#        12    0.221    0.018    0.626    0.052 _json.py:971(_combine_lines)
#        12    0.192    0.016    5.453    0.454 _json.py:1397(_parse)
#        48    0.183    0.004    0.183    0.004 {method 'join' of 'str' objects}
#       108    0.176    0.002    0.284    0.003 managers.py:2276(_merge_blocks)
#    117408    0.170    0.000    0.170    0.000 {method 'strip' of 'str' objects}
#        96    0.163    0.002    0.169    0.002 datetimes.py:482(_to_datetime_with_unit)
#       252    0.118    0.000    0.122    0.000 construction.py:1028(convert)
#    117419    0.116    0.000    0.123    0.000 construction.py:915(<genexpr>)
#       228    0.104    0.000    0.113    0.000 managers.py:2246(_stack_arrays)
#        72    0.103    0.001    0.103    0.001 shape_base.py:220(vstack)
#        36    0.078    0.002    0.505    0.014 construction.py:96(arrays_to_mgr)
#     49773    0.064    0.000    0.064    0.000 {built-in method _codecs.utf_8_decode}
#         1    0.053    0.053    8.538    8.538 2083523560.py:7(q1_pandas)
#         3    0.050    0.017    0.055    0.018 algorithms.py:548(factorize_array)
#        12    0.040    0.003    0.389    0.032 _json.py:1473(_try_convert_dates)
#        12    0.039    0.003    0.067    0.006 algorithms.py:1667(map_array)
#         1    0.038    0.038    0.044    0.044 concat.py:94(concatenate_managers)
#    117419    0.035    0.000    0.205    0.000 _json.py:976(<genexpr>)
#        12    0.030    0.003    0.634    0.053 _json.py:1463(_try_convert_types)
#        80    0.028    0.000    0.028    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#    117407    0.028    0.000    0.028    0.000 2083523560.py:23(<lambda>)
#        12    0.025    0.002    0.025    0.002 construction.py:922(<listcomp>)
#        10    0.024    0.002    0.024    0.002 array_ops.py:113(comp_method_OBJECT_ARRAY)
#     49773    0.022    0.000    0.087    0.000 <frozen codecs>:319(decode)
#      3598    0.020    0.000    0.054    0.000 ipkernel.py:775(_clean_thread_parent_frames)
#         1    0.019    0.019    0.019    0.019 sorting.py:246(_decons_group_index)
#        12    0.017    0.001    0.222    0.019 _json.py:976(<listcomp>)
#      1799    0.015    0.000    0.017    0.000 threading.py:1501(enumerate)
#        12    0.014    0.001    0.014    0.001 datetimes.py:1436(date)
#       108    0.013    0.000    0.799    0.007 datetimes.py:149(should_cache)
#      1186    0.011    0.000    0.011    0.000 {built-in method numpy.empty}
# 62238/60522    0.010    0.000    0.015    0.000 {built-in method builtins.isinstance}
#      1799    0.009    0.000    0.015    0.000 ipkernel.py:790(<setcomp>)
#       878    0.009    0.000    0.023    0.000 base.py:549(find)
#    124637    0.007    0.000    0.007    0.000 {method 'keys' of 'dict' objects}
#     12593    0.007    0.000    0.007    0.000 threading.py:1168(ident)
#      8470    0.006    0.000    0.007    0.000 base.py:238(construct_from_string)
#        37    0.006    0.000    0.006    0.000 take.py:120(_take_nd_ndarray)
#        36    0.005    0.000    0.124    0.003 managers.py:2190(_form_blocks)
#       417    0.005    0.000    0.006    0.000 cast.py:1156(maybe_infer_to_datetimelike)
#       571    0.005    0.000    0.005    0.000 {method 'astype' of 'numpy.ndarray' objects}
#       230    0.004    0.000    0.028    0.000 series.py:389(__init__)
#         3    0.004    0.001    0.004    0.001 algorithms.py:280(_check_object_for_strings)
#      2549    0.004    0.000    0.009    0.000 generic.py:6301(__setattr__)
#        73    0.004    0.000    0.004    0.000 {method 'copy' of 'numpy.ndarray' objects}
#       541    0.003    0.000    0.005    0.000 managers.py:1012(iget)
#       847    0.003    0.000    0.004    0.000 generic.py:278(__init__)
#       790    0.003    0.000    0.018    0.000 common.py:1596(pandas_dtype)
# 10015/6601    0.003    0.000    0.005    0.000 {built-in method builtins.len}
#       537    0.003    0.000    0.015    0.000 construction.py:517(sanitize_array)
#         1    0.003    0.003    0.005    0.005 sorting.py:687(compress_group_index)
#       651    0.003    0.000    0.004    0.000 generic.py:6236(__finalize__)
#        12    0.002    0.000    0.560    0.047 construction.py:793(to_arrays)
#       738    0.002    0.000    0.004    0.000 numeric.py:290(full)
#       384    0.002    0.000    0.011    0.000 astype.py:56(_astype_nansafe)
#       615    0.002    0.000    0.005    0.000 _dtype.py:350(_name_get)
#       276    0.002    0.000    0.072    0.000 _json.py:1223(_try_convert_data)
#       551    0.002    0.000    0.023    0.000 frame.py:4626(_get_item_cache)
#      3973    0.002    0.000    0.004    0.000 generic.py:42(_instancecheck)
#        67    0.002    0.000    0.008    0.000 base.py:475(__new__)
#       585    0.002    0.000    0.002    0.000 base.py:3777(get_loc)
#        37    0.002    0.000    0.294    0.008 managers.py:1782(_consolidate_inplace)
#        26    0.002    0.000    0.002    0.000 {built-in method posix.stat}
#        36    0.002    0.000    0.200    0.006 _json.py:1315(_try_convert_to_date)
#      3973    0.002    0.000    0.002    0.000 generic.py:37(_check)
#        36    0.002    0.000    1.077    0.030 frame.py:694(__init__)
#      1982    0.001    0.000    0.002    0.000 managers.py:1993(dtype)
# 6891/6843    0.001    0.000    0.016    0.000 {built-in method builtins.getattr}
#      1102    0.001    0.000    0.002    0.000 base.py:5373(__getitem__)
#       541    0.001    0.000    0.019    0.000 frame.py:3983(_ixs)
#         6    0.001    0.000    0.001    0.000 {method 'take' of 'numpy.ndarray' objects}
#       602    0.001    0.000    0.002    0.000 blocks.py:2674(get_block_type)
#        24    0.001    0.000    0.564    0.024 _json.py:1433(_process_converter)
#       228    0.001    0.000    0.003    0.000 _asarray.py:27(require)
#        36    0.001    0.000    0.008    0.000 construction.py:596(_homogenize)
#       541    0.001    0.000    0.010    0.000 frame.py:4608(_box_col_values)
#       388    0.001    0.000    0.031    0.000 managers.py:317(apply)
#       844    0.001    0.000    0.003    0.000 numerictypes.py:471(issubdtype)
#         3    0.001    0.000    0.029    0.010 algorithms.py:1452(safe_sort)
#       646    0.001    0.000    0.001    0.000 warnings.py:467(__enter__)
#       229    0.001    0.000    0.003    0.000 managers.py:1863(from_array)
#       466    0.001    0.000    0.005    0.000 base.py:7593(ensure_index)
#       258    0.001    0.000    0.001    0.000 {built-in method numpy.array}
#       628    0.001    0.000    0.002    0.000 warnings.py:182(_add_filter)
#       340    0.001    0.000    0.002    0.000 blocks.py:2645(maybe_coerce_values)
#        37    0.001    0.000    0.002    0.000 cast.py:123(maybe_convert_platform)
#       220    0.001    0.000    0.001    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#       252    0.001    0.000    0.003    0.000 blocks.py:225(_consolidate_key)
#       384    0.001    0.000    0.029    0.000 astype.py:191(astype_array_safe)
#       770    0.001    0.000    0.001    0.000 dtypes.py:1305(construct_from_string)
#        36    0.001    0.000    0.290    0.008 managers.py:2259(_consolidate)
#        99    0.001    0.000    0.003    0.000 blocks.py:2703(new_block_2d)
#         1    0.001    0.001    0.006    0.006 frame.py:6239(reset_index)
#       770    0.001    0.000    0.001    0.000 dtypes.py:1054(construct_from_string)
#      1688    0.001    0.000    0.001    0.000 numerictypes.py:289(issubclass_)
#      3598    0.001    0.000    0.001    0.000 {method 'values' of 'dict' objects}
#      1799    0.001    0.000    0.001    0.000 {method '__exit__' of '_thread.RLock' objects}
#         2    0.001    0.000    0.001    0.000 {built-in method builtins.compile}
#       108    0.001    0.000    0.985    0.009 datetimes.py:673(to_datetime)
#       108    0.001    0.000    0.810    0.008 datetimes.py:209(_maybe_cache)
#      1982    0.001    0.000    0.003    0.000 series.py:707(dtype)
#       528    0.001    0.000    0.021    0.000 frame.py:1496(items)
#      5012    0.001    0.000    0.001    0.000 {built-in method builtins.issubclass}
#        36    0.001    0.000    0.002    0.000 managers.py:1778(<listcomp>)
#      2079    0.001    0.000    0.001    0.000 __init__.py:34(using_copy_on_write)
#         2    0.001    0.000    0.112    0.056 ops.py:700(size)
#       847    0.001    0.000    0.001    0.000 flags.py:51(__init__)
#       770    0.001    0.000    0.001    0.000 dtypes.py:831(construct_from_string)
#        77    0.001    0.000    0.001    0.000 base.py:5323(__contains__)
#       267    0.001    0.000    0.004    0.000 generic.py:807(_set_axis)
#       366    0.001    0.000    0.001    0.000 series.py:734(name)
#       551    0.001    0.000    0.005    0.000 frame.py:678(_constructor_sliced_from_mgr)
#   821/794    0.001    0.000    0.005    0.000 {built-in method builtins.all}
#       384    0.001    0.000    0.047    0.000 generic.py:6463(astype)
# 1035/1025    0.001    0.000    0.001    0.000 {built-in method numpy.asarray}
#      1987    0.001    0.000    0.001    0.000 range.py:999(__len__)
#       424    0.001    0.000    0.002    0.000 inference.py:273(is_dict_like)
#       126    0.001    0.000    0.001    0.000 base.py:649(_simple_new)
#         3    0.001    0.000    0.001    0.000 concat.py:52(concat_compat)
#       646    0.001    0.000    0.001    0.000 warnings.py:488(__exit__)
#       384    0.001    0.000    0.032    0.000 managers.py:421(astype)
#       251    0.001    0.000    0.001    0.000 blocks.py:2716(new_block)
#      1534    0.001    0.000    0.001    0.000 {built-in method _abc._abc_instancecheck}
#       264    0.001    0.000    0.001    0.000 config.py:127(_get_single_key)
#       228    0.001    0.000    0.001    0.000 _asarray.py:109(<setcomp>)
#        57    0.001    0.000    0.012    0.000 frame.py:4062(__getitem__)
#        12    0.001    0.000    0.033    0.003 _json.py:1199(_convert_axes)
#      1780    0.001    0.000    0.001    0.000 {built-in method builtins.hasattr}
#       615    0.001    0.000    0.002    0.000 _dtype.py:334(_name_includes_bit_suffix)
#       770    0.001    0.000    0.001    0.000 dtypes.py:1835(construct_from_string)
#      1171    0.001    0.000    0.001    0.000 inference.py:334(is_hashable)
#       581    0.001    0.000    0.003    0.000 generic.py:339(_from_mgr)
#       470    0.001    0.000    0.001    0.000 construction.py:481(ensure_wrapped_if_datetimelike)
#       264    0.001    0.000    0.001    0.000 config.py:635(_get_root)
#         7    0.001    0.000    0.001    0.000 missing.py:305(_isna_string_dtype)
#       770    0.001    0.000    0.001    0.000 dtypes.py:342(construct_from_string)
#        97    0.001    0.000    0.001    0.000 base.py:836(__iter__)
#       770    0.001    0.000    0.001    0.000 dtypes.py:2228(construct_from_string)
#        12    0.001    0.000    0.123    0.010 construction.py:928(_finalize_columns_and_data)
#         1    0.001    0.001    0.002    0.002 sorting.py:718(_reorder_by_uniques)
#       264    0.001    0.000    0.003    0.000 config.py:145(_get_option)
#       541    0.001    0.000    0.002    0.000 series.py:1471(_set_as_cached)
#         1    0.001    0.001    0.001    0.001 sorting.py:122(get_group_index)
#        36    0.001    0.000    0.419    0.012 managers.py:2121(create_block_manager_from_column_arrays)
#       276    0.001    0.000    0.002    0.000 series.py:784(name)
#       770    0.001    0.000    0.001    0.000 string_.py:140(construct_from_string)
#       384    0.001    0.000    0.013    0.000 common.py:1277(is_extension_array_dtype)
#       628    0.001    0.000    0.001    0.000 {method 'remove' of 'list' objects}
#       756    0.001    0.000    0.001    0.000 managers.py:2177(_grouping_func)
#       333    0.001    0.000    0.002    0.000 base.py:7688(maybe_extract_name)
#       504    0.001    0.000    0.002    0.000 warnings.py:166(simplefilter)
#         1    0.001    0.001    0.001    0.001 {built-in method _imp.create_dynamic}
#        12    0.001    0.000    0.001    0.000 datetimes.py:923(tz_localize)
#       158    0.001    0.000    0.001    0.000 range.py:201(_simple_new)
#       808    0.001    0.000    0.001    0.000 {method 'match' of 're.Pattern' objects}
#       124    0.001    0.000    0.002    0.000 warnings.py:131(filterwarnings)
#       612    0.001    0.000    0.001    0.000 common.py:301(maybe_iterable_to_list)
#        24    0.001    0.000    0.002    0.000 construction.py:487(<listcomp>)
#       120    0.001    0.000    0.003    0.000 concat.py:389(is_na)
#       384    0.001    0.000    0.012    0.000 astype.py:157(astype_array)
#        12    0.000    0.000    6.120    0.510 _json.py:1185(parse)
#       267    0.000    0.000    0.001    0.000 managers.py:236(set_axis)
#       646    0.000    0.000    0.000    0.000 warnings.py:441(__init__)
#       462    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#      1056    0.000    0.000    0.001    0.000 series.py:831(_values)
#        15    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#       250    0.000    0.000    0.001    0.000 generic.py:6284(__getattr__)
#       706    0.000    0.000    0.001    0.000 construction.py:416(extract_array)
#      1056    0.000    0.000    0.001    0.000 managers.py:2004(internal_values)
#        24    0.000    0.000    0.002    0.000 datetimes.py:2184(_sequence_to_dt64)
#      1852    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#       571    0.000    0.000    0.001    0.000 blocks.py:1253(iget)
#    160/19    0.000    0.000    0.001    0.000 {built-in method _abc._abc_subclasscheck}
#      1371    0.000    0.000    0.001    0.000 common.py:1270(is_1d_only_ea_dtype)
#       320    0.000    0.000    0.001    0.000 common.py:572(condition)
#       384    0.000    0.000    0.030    0.000 blocks.py:723(astype)
#       132    0.000    0.000    0.001    0.000 dtypes.py:867(__str__)
#         3    0.000    0.000    0.085    0.028 algorithms.py:610(factorize)
#        19    0.000    0.000    0.002    0.000 missing.py:261(_isna_array)
#        24    0.000    0.000    0.003    0.000 datetimes.py:329(_from_sequence_not_strict)
#       279    0.000    0.000    0.001    0.000 common.py:1571(validate_all_hashable)
#      3327    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#       872    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x7f8757e74a40}
#       322    0.000    0.000    0.000    0.000 blocks.py:214(is_extension)
#        27    0.000    0.000    0.001    0.000 base.py:842(_engine)
#       429    0.000    0.000    0.001    0.000 construction.py:696(_sanitize_ndim)
#       651    0.000    0.000    0.000    0.000 flags.py:87(allows_duplicate_labels)
#        65    0.000    0.000    0.001    0.000 base.py:82(shape)
#       267    0.000    0.000    0.001    0.000 base.py:86(_validate_set_axis)
#        14    0.000    0.000    0.001    0.000 _function_base_impl.py:5456(insert)
#      1284    0.000    0.000    0.001    0.000 inference.py:300(<genexpr>)
#        72    0.000    0.000    0.002    0.000 fromnumeric.py:1130(argsort)
#      35/5    0.000    0.000    0.001    0.000 _parser.py:516(_parse)
#      1534    0.000    0.000    0.002    0.000 <frozen abc>:117(__instancecheck__)
#       525    0.000    0.000    0.001    0.000 base.py:74(__len__)
#        73    0.000    0.000    0.002    0.000 fromnumeric.py:51(_wrapfunc)
#       320    0.000    0.000    0.002    0.000 common.py:536(is_string_dtype)
#       252    0.000    0.000    0.001    0.000 _json.py:1483(is_ok)
#        46    0.000    0.000    0.006    0.000 series.py:6201(_construct_result)
#       798    0.000    0.000    0.000    0.000 managers.py:1837(__init__)
#        90    0.000    0.000    0.000    0.000 generic.py:586(_get_axis)
#        12    0.000    0.000    6.121    0.510 _json.py:1033(_get_object_parser)
#        51    0.000    0.000    0.000    0.000 blocks.py:2811(ensure_block_shape)
#        50    0.000    0.000    0.004    0.000 {built-in method builtins.sorted}
#       357    0.000    0.000    0.002    0.000 common.py:1375(_is_dtype)
#      1102    0.000    0.000    0.000    0.000 common.py:152(cast_scalar_indexer)
#        24    0.000    0.000    0.315    0.013 construction.py:423(dict_to_mgr)
#        24    0.000    0.000    0.009    0.000 frame.py:4271(__setitem__)
#       504    0.000    0.000    0.004    0.000 managers.py:2264(<lambda>)
#       146    0.000    0.000    0.001    0.000 api.py:386(default_index)
#       144    0.000    0.000    0.002    0.000 missing.py:808(<genexpr>)
#        12    0.000    0.000    0.002    0.000 arraylike.py:253(array_ufunc)
#        14    0.000    0.000    0.005    0.000 managers.py:1347(insert)
#       264    0.000    0.000    0.000    0.000 config.py:676(_translate_key)
#       124    0.000    0.000    0.000    0.000 blocks.py:2795(extend_blocks)
#        48    0.000    0.000    0.000    0.000 datetimes.py:304(_simple_new)
#        24    0.000    0.000    0.004    0.000 datetimes.py:320(__new__)
#        14    0.000    0.000    0.003    0.000 base.py:6956(insert)
#         1    0.000    0.000    0.000    0.000 {method 'put' of 'numpy.ndarray' objects}
#        37    0.000    0.000    0.001    0.000 cast.py:1579(construct_1d_object_array_from_listlike)
#      1248    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#        72    0.000    0.000    0.000    0.000 shape_base.py:80(atleast_2d)
#       108    0.000    0.000    0.169    0.002 datetimes.py:314(_convert_listlike_datetimes)
#       180    0.000    0.000    0.003    0.000 generic.py:511(_validate_dtype)
#       119    0.000    0.000    0.002    0.000 __init__.py:272(_compile)
#      40/5    0.000    0.000    0.000    0.000 _compiler.py:37(_compile)
#        24    0.000    0.000    0.001    0.000 datetimelike.py:373(__getitem__)
#       642    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#       983    0.000    0.000    0.000    0.000 blocks.py:718(dtype)
#        36    0.000    0.000    0.002    0.000 _strptime.py:309(_strptime)
#       405    0.000    0.000    0.000    0.000 construction.py:735(_sanitize_str_dtypes)
#       615    0.000    0.000    0.000    0.000 _dtype.py:24(_kind_name)
#        37    0.000    0.000    0.002    0.000 managers.py:1772(_consolidate_check)
#        12    0.000    0.000    0.122    0.010 construction.py:1070(<listcomp>)
#        25    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#        12    0.000    0.000    0.070    0.006 apply.py:1482(apply_standard)
#        15    0.000    0.000    0.001    0.000 base.py:2313(is_unique)
#        12    0.000    0.000    0.000    0.000 {built-in method _operator.gt}
#        11    0.000    0.000    0.000    0.000 utils.py:239(maybe_convert_indices)
#       130    0.000    0.000    0.000    0.000 concat.py:587(<genexpr>)
#        12    0.000    0.000    0.001    0.000 astype.py:138(_astype_float_to_int_nansafe)
#       264    0.000    0.000    0.000    0.000 config.py:617(_select_options)
#        37    0.000    0.000    0.000    0.000 cast.py:550(maybe_promote)
#       252    0.000    0.000    0.001    0.000 blocks.py:219(_can_consolidate)
#       297    0.000    0.000    0.000    0.000 base.py:909(__len__)
#       267    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#       516    0.000    0.000    0.000    0.000 series.py:865(_references)
#       144    0.000    0.000    0.001    0.000 missing.py:184(_isna)
#        72    0.000    0.000    0.001    0.000 construction.py:769(_try_cast)
#        24    0.000    0.000    0.006    0.000 frame.py:4481(_set_item_mgr)
#        36    0.000    0.000    0.000    0.000 construction.py:196(mgr_to_mgr)
#       339    0.000    0.000    0.000    0.000 common.py:529(is_string_or_object_np_dtype)
#       144    0.000    0.000    0.000    0.000 common.py:1434(_is_dtype_type)
#       402    0.000    0.000    0.000    0.000 common.py:1399(_get_dtype)
#       559    0.000    0.000    0.000    0.000 common.py:1590(<genexpr>)
#      1035    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#        72    0.000    0.000    0.000    0.000 managers.py:2285(<listcomp>)
#      1920    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#       247    0.000    0.000    0.000    0.000 __init__.py:55(using_pyarrow_string_dtype)
#       120    0.000    0.000    0.000    0.000 concat.py:322(_get_block_for_concat_plan)
#       350    0.000    0.000    0.001    0.000 common.py:568(require_length_match)
#       796    0.000    0.000    0.000    0.000 managers.py:1940(_block)
#       216    0.000    0.000    0.001    0.000 dtypes.py:880(__eq__)
#        24    0.000    0.000    0.001    0.000 construction.py:481(<listcomp>)
#        22    0.000    0.000    0.025    0.001 array_ops.py:288(comparison_op)
#       252    0.000    0.000    0.046    0.000 _json.py:1470(<lambda>)
#      1115    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#      1314    0.000    0.000    0.000    0.000 generic.py:405(flags)
#       589    0.000    0.000    0.000    0.000 managers.py:180(blknos)
#        14    0.000    0.000    0.001    0.000 cast.py:1604(maybe_cast_to_integer_array)
#        24    0.000    0.000    0.000    0.000 _mixins.py:278(__getitem__)
#        12    0.000    0.000    0.001    0.000 _parser.py:666(_parse)
#        52    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.ndarray' objects}
#       575    0.000    0.000    0.000    0.000 __init__.py:42(warn_copy_on_write)
#       649    0.000    0.000    0.000    0.000 managers.py:196(blklocs)
#       429    0.000    0.000    0.000    0.000 construction.py:758(_maybe_repeat)
#       286    0.000    0.000    0.000    0.000 base.py:831(_reset_identity)
#        18    0.000    0.000    0.002    0.000 base.py:674(_with_infer)
#       515    0.000    0.000    0.001    0.000 series.py:914(__len__)
#         1    0.000    0.000    0.001    0.001 concat.py:296(_get_combined_plan)
#       108    0.000    0.000    0.000    0.000 cast.py:1518(construct_1d_arraylike_from_scalar)
#        36    0.000    0.000    0.000    0.000 dtypes.py:751(__init__)
#         2    0.000    0.000    0.045    0.022 concat.py:622(get_result)
#        12    0.000    0.000    0.019    0.002 accessors.py:88(_delegate_property_get)
#        12    0.000    0.000    0.000    0.000 managers.py:1066(iset)
#         2    0.000    0.000    0.001    0.000 grouper.py:846(get_grouper)
#       133    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1207(_handle_fromlist)
#         3    0.000    0.000    0.002    0.001 algorithms.py:1131(take)
#       553    0.000    0.000    0.000    0.000 managers.py:246(items)
#       126    0.000    0.000    0.000    0.000 missing.py:673(na_value_for_dtype)
#       772    0.000    0.000    0.000    0.000 {method 'search' of 're.Pattern' objects}
#       384    0.000    0.000    0.000    0.000 inspect.py:292(isclass)
#        84    0.000    0.000    0.000    0.000 blocks.py:324(slice_block_columns)
#         2    0.000    0.000    0.000    0.000 {built-in method posix.mkdir}
#        22    0.000    0.000    0.028    0.001 series.py:6110(_cmp_method)
#        41    0.000    0.000    0.000    0.000 blocks.py:292(make_block_same_class)
#        10    0.000    0.000    0.001    0.000 managers.py:958(fast_xs)
#        14    0.000    0.000    0.000    0.000 managers.py:1402(_insert_update_mgr_locs)
#        28    0.000    0.000    0.000    0.000 _function_base_impl.py:5644(append)
#       719    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#        12    0.000    0.000    0.000    0.000 {method 'fill' of 'numpy.ndarray' objects}
#        10    0.000    0.000    0.003    0.000 concat.py:572(_is_uniform_join_units)
#        24    0.000    0.000    0.000    0.000 datetimelike.py:2425(ensure_arraylike_for_datetimelike)
#       119    0.000    0.000    0.002    0.000 concat.py:597(<genexpr>)
#        50    0.000    0.000    0.000    0.000 frame.py:4623(_clear_item_cache)
#        24    0.000    0.000    0.003    0.000 series.py:6123(_logical_method)
#        24    0.000    0.000    0.001    0.000 array_ops.py:393(logical_op)
#        24    0.000    0.000    0.001    0.000 datetimes.py:2428(maybe_convert_dtype)
#        12    0.000    0.000    0.000    0.000 construction.py:532(treat_as_nested)
#       159    0.000    0.000    0.001    0.000 {method 'all' of 'numpy.ndarray' objects}
#        61    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#       408    0.000    0.000    0.000    0.000 datetimes.py:551(dtype)
#        24    0.000    0.000    0.009    0.000 frame.py:4514(_set_item)
#        37    0.000    0.000    0.007    0.000 take.py:59(take_nd)
#        79    0.000    0.000    0.000    0.000 indexing.py:2765(check_dict_or_set_indexers)
#      1246    0.000    0.000    0.000    0.000 typing.py:2287(cast)
#       264    0.000    0.000    0.000    0.000 config.py:649(_get_deprecated_option)
#        12    0.000    0.000    0.561    0.047 construction.py:506(nested_data_to_arrays)
#        84    0.000    0.000    0.000    0.000 dtypes.py:870(name)
#       448    0.000    0.000    0.000    0.000 blocks.py:266(mgr_locs)
#        14    0.000    0.000    0.000    0.000 numeric.py:1448(moveaxis)
#       651    0.000    0.000    0.000    0.000 generic.py:363(attrs)
#        26    0.000    0.000    0.004    0.000 frame.py:5242(_sanitize_column)
#        24    0.000    0.000    0.000    0.000 common.py:1163(is_float_dtype)
#       145    0.000    0.000    0.000    0.000 generic.py:572(_get_axis_number)
#       663    0.000    0.000    0.000    0.000 flags.py:55(allows_duplicate_labels)
#         1    0.000    0.000    0.007    0.007 series.py:1624(reset_index)
#        24    0.000    0.000    0.000    0.000 managers.py:2226(<listcomp>)
#        37    0.000    0.000    0.002    0.000 managers.py:1764(is_consolidated)
#         2    0.000    0.000    0.001    0.001 __init__.py:1(<module>)
#        18    0.000    0.000    0.000    0.000 common.py:231(asarray_tuplesafe)
#        32    0.000    0.000    0.004    0.000 blocks.py:1287(take_nd)
#       739    0.000    0.000    0.000    0.000 multiarray.py:1098(copyto)
#        28    0.000    0.000    0.000    0.000 numeric.py:1386(normalize_axis_tuple)
#       346    0.000    0.000    0.001    0.000 base.py:5144(_values)
#        12    0.000    0.000    0.004    0.000 managers.py:623(reindex_indexer)
#        46    0.000    0.000    0.032    0.001 common.py:62(new_method)
#        60    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#       110    0.000    0.000    0.000    0.000 common.py:1331(is_ea_or_datetimelike_dtype)
#       228    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#        48    0.000    0.000    0.000    0.000 datetimes.py:103(tz_to_dtype)
#        10    0.000    0.000    0.000    0.000 range.py:1148(take)
#        55    0.000    0.000    0.000    0.000 base.py:609(_dtype_to_subclass)
#        12    0.000    0.000    0.000    0.000 inference.py:404(is_dataclass)
#        37    0.000    0.000    0.000    0.000 take.py:564(_take_preprocess_indexer_and_fill_value)
#       144    0.000    0.000    0.001    0.000 missing.py:101(isna)
#       113    0.000    0.000    0.000    0.000 enum.py:193(__get__)
#        34    0.000    0.000    0.000    0.000 base.py:5552(equals)
#        12    0.000    0.000    0.003    0.000 generic.py:2167(__array_ufunc__)
#        12    0.000    0.000    0.001    0.000 series.py:6480(all)
#        72    0.000    0.000    0.000    0.000 shape_base.py:208(_arrays_for_stack_dispatcher)
#        10    0.000    0.000    0.001    0.000 generic.py:4159(xs)
#       121    0.000    0.000    0.000    0.000 blocks.py:230(_can_hold_na)
#        55    0.000    0.000    0.000    0.000 base.py:591(_ensure_array)
#        11    0.000    0.000    0.005    0.000 generic.py:4027(take)
#        11    0.000    0.000    0.000    0.000 cast.py:1432(find_common_type)
#        24    0.000    0.000    0.003    0.000 frame.py:12675(_reindex_for_setitem)
#     46/11    0.000    0.000    0.000    0.000 _parser.py:178(getwidth)
#       192    0.000    0.000    0.001    0.000 base.py:84(<genexpr>)
#        72    0.000    0.000    0.000    0.000 shape_base.py:216(_vhstack_dispatcher)
#       159    0.000    0.000    0.001    0.000 _methods.py:67(_all)
#        10    0.000    0.000    0.001    0.000 series.py:2691(idxmax)
#        12    0.000    0.000    0.000    0.000 datetimelike.py:2353(copy)
#        12    0.000    0.000    0.000    0.000 _json.py:1138(__init__)
#        14    0.000    0.000    0.000    0.000 managers.py:2311(_fast_count_smallints)
#        45    0.000    0.000    0.000    0.000 common.py:1198(is_bool_dtype)
#         4    0.000    0.000    0.000    0.000 {built-in method io.open_code}
#        27    0.000    0.000    0.000    0.000 base.py:5170(_get_engine_target)
#        12    0.000    0.000    0.000    0.000 range.py:137(__new__)
#       130    0.000    0.000    0.000    0.000 concat.py:584(<genexpr>)
#        49    0.000    0.000    0.000    0.000 frame.py:1643(__len__)
#         6    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1607(find_spec)
#       365    0.000    0.000    0.000    0.000 _parser.py:168(__getitem__)
#        24    0.000    0.000    0.000    0.000 {built-in method _operator.or_}
#       297    0.000    0.000    0.000    0.000 _parser.py:240(__next)
#        10    0.000    0.000    0.007    0.001 frame.py:4130(_getitem_bool_array)
#       108    0.000    0.000    0.000    0.000 base.py:675(empty)
#       235    0.000    0.000    0.000    0.000 _parser.py:261(get)
#        10    0.000    0.000    0.001    0.000 utils.py:419(check_array_indexer)
#       108    0.000    0.000    0.000    0.000 base.py:448(size)
#        48    0.000    0.000    0.000    0.000 _internal.py:941(npy_ctypes_check)
#        11    0.000    0.000    0.005    0.000 managers.py:869(take)
#        14    0.000    0.000    0.000    0.000 managers.py:1412(_insert_update_blklocs_and_blknos)
#        12    0.000    0.000    0.001    0.000 range.py:237(_data)
#        24    0.000    0.000    0.000    0.000 _parser.py:77(get_token)
#        12    0.000    0.000    0.000    0.000 accessors.py:611(__new__)
#        12    0.000    0.000    0.070    0.006 series.py:4789(apply)
#        80    0.000    0.000    0.000    0.000 common.py:137(is_object_dtype)
#         2    0.000    0.000    0.001    0.000 frame.py:9041(groupby)
#       272    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
#         2    0.000    0.000    0.003    0.001 frame.py:5095(insert)
#       388    0.000    0.000    0.000    0.000 managers.py:344(<dictcomp>)
#        12    0.000    0.000    0.001    0.000 frame.py:4470(_iset_item_mgr)
#       103    0.000    0.000    0.000    0.000 common.py:372(apply_if_callable)
#         1    0.000    0.000    0.001    0.001 selectn.py:90(compute)
#       496    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#        79    0.000    0.000    0.000    0.000 managers.py:1392(<genexpr>)
#        19    0.000    0.000    0.002    0.000 missing.py:779(isna_all)
#        12    0.000    0.000    0.000    0.000 array_ops.py:189(_na_arithmetic_op)
#        36    0.000    0.000    0.000    0.000 dtypes.py:783(_creso)
#        12    0.000    0.000    0.000    0.000 accessor.py:220(__get__)
#         2    0.000    0.000    0.001    0.000 groupby.py:1296(__init__)
#        26    0.000    0.000    0.000    0.000 common.py:1081(is_numeric_dtype)
#         3    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:1054(_find_spec)
#        12    0.000    0.000    0.001    0.000 datetimes.py:286(tz_localize)
#       180    0.000    0.000    0.000    0.000 dtypes.py:790(unit)
#        23    0.000    0.000    0.000    0.000 missing.py:564(_array_equivalent_object)
#        24    0.000    0.000    0.000    0.000 datetimelike.py:390(_get_getitem_freq)
#       585    0.000    0.000    0.000    0.000 base.py:6672(_maybe_cast_indexer)
#        12    0.000    0.000    0.000    0.000 _parser.py:199(split)
#        12    0.000    0.000    0.002    0.000 indexing.py:1176(__getitem__)
#        12    0.000    0.000    0.000    0.000 accessors.py:59(__init__)
#       119    0.000    0.000    0.002    0.000 __init__.py:225(compile)
#        48    0.000    0.000    0.000    0.000 dtypes.py:130(__repr__)
#        11    0.000    0.000    0.006    0.001 generic.py:4142(_take_with_is_copy)
#       192    0.000    0.000    0.000    0.000 dtypes.py:804(tz)
#        72    0.000    0.000    0.000    0.000 managers.py:2294(<listcomp>)
#        22    0.000    0.000    0.000    0.000 common.py:992(is_numeric_v_string_like)
#        10    0.000    0.000    0.000    0.000 base.py:680(argmax)
#        21    0.000    0.000    0.000    0.000 common.py:97(is_bool_indexer)
#        72    0.000    0.000    0.000    0.000 datetimes.py:576(tz)
#        24    0.000    0.000    0.000    0.000 base.py:1045(astype)
#        56    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#       221    0.000    0.000    0.000    0.000 _parser.py:176(append)
#        10    0.000    0.000    0.001    0.000 indexing.py:2632(check_bool_indexer)
#       3/2    0.000    0.000    0.005    0.002 <frozen importlib._bootstrap>:1165(_find_and_load)
#        12    0.000    0.000    0.122    0.010 construction.py:1006(convert_object_array)
#        12    0.000    0.000    0.067    0.006 base.py:891(_map_values)
#        12    0.000    0.000    0.000    0.000 blocks.py:274(make_block)
#         4    0.000    0.000    0.000    0.000 cast.py:972(coerce_indexer_dtype)
#        10    0.000    0.000    0.002    0.000 indexing.py:1397(_getitem_axis)
#        29    0.000    0.000    0.000    0.000 missing.py:728(is_valid_na_for_dtype)
#        12    0.000    0.000    0.001    0.000 _mixins.py:78(method)
#        83    0.000    0.000    0.000    0.000 series.py:660(_constructor)
#        12    0.000    0.000    0.000    0.000 _parser.py:62(__init__)
#        36    0.000    0.000    0.000    0.000 {built-in method _locale.setlocale}
#        36    0.000    0.000    0.000    0.000 datetimelike.py:319(asi8)
#        24    0.000    0.000    0.000    0.000 array_ops.py:352(na_logical_op)
#        12    0.000    0.000    0.070    0.006 apply.py:1409(apply)
#         2    0.000    0.000    0.000    0.000 {built-in method posix.open}
#         1    0.000    0.000    0.005    0.005 common.py:664(get_handle)
#        46    0.000    0.000    0.000    0.000 common.py:81(get_op_result_name)
#      11/5    0.000    0.000    0.001    0.000 _parser.py:456(_parse_sub)
#         1    0.000    0.000    0.002    0.002 concat.py:457(_concatenate_join_units)
#         1    0.000    0.000    0.000    0.000 {built-in method io.open}
#        12    0.000    0.000    0.000    0.000 series.py:6418(_reduce)
#       105    0.000    0.000    0.000    0.000 common.py:121(classes)
#         2    0.000    0.000    0.003    0.001 <frozen importlib._bootstrap_external>:1007(get_code)
#        14    0.000    0.000    0.000    0.000 base.py:5295(_validate_fill_value)
#        48    0.000    0.000    0.000    0.000 array_ops.py:410(fill_bool)
#        36    0.000    0.000    0.000    0.000 {built-in method numpy.datetime_data}
#        12    0.000    0.000    0.000    0.000 construction.py:950(_validate_or_indexify_columns)
#        10    0.000    0.000    0.004    0.000 managers.py:687(<listcomp>)
#        38    0.000    0.000    0.002    0.000 concat.py:418(<genexpr>)
#        17    0.000    0.000    0.000    0.000 managers.py:1850(from_blocks)
#        24    0.000    0.000    0.000    0.000 generic.py:4402(_check_setitem_copy)
#         2    0.000    0.000    0.000    0.000 __init__.py:339(__init__)
#        12    0.000    0.000    0.000    0.000 _parser.py:395(__init__)
#       3/1    0.000    0.000    9.151    9.151 {built-in method builtins.exec}
#        36    0.000    0.000    0.000    0.000 locale.py:396(normalize)
#        20    0.000    0.000    0.000    0.000 base.py:5437(_can_hold_identifiers_and_holds_name)
#        23    0.000    0.000    0.000    0.000 inference.py:195(is_array_like)
#        12    0.000    0.000    0.000    0.000 _parser.py:221(__init__)
#        36    0.000    0.000    0.000    0.000 datetimelike.py:2148(_creso)
#        27    0.000    0.000    0.000    0.000 base.py:456(_engine_type)
#        10    0.000    0.000    0.000    0.000 nanops.py:1109(nanargmax)
#        12    0.000    0.000    0.000    0.000 apply.py:1377(__init__)
#        12    0.000    0.000    0.002    0.000 accessors.py:70(_get_values)
#        10    0.000    0.000    0.000    0.000 cast.py:1391(np_find_common_type)
#        12    0.000    0.000    0.001    0.000 concat.py:431(get_reindexed_values)
#        36    0.000    0.000    0.000    0.000 locale.py:594(getlocale)
#       105    0.000    0.000    0.000    0.000 common.py:123(<lambda>)
#       3/2    0.000    0.000    0.005    0.002 <frozen importlib._bootstrap>:1120(_find_and_load_unlocked)
#         2    0.000    0.000    0.112    0.056 groupby.py:2985(size)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:185(_write_atomic)
#        36    0.000    0.000    0.000    0.000 _strptime.py:26(_getlang)
#        13    0.000    0.000    0.000    0.000 common.py:633(is_integer_dtype)
#         2    0.000    0.000    0.000    0.000 multi.py:325(__new__)
#        60    0.000    0.000    0.000    0.000 generic.py:667(_info_axis)
#        12    0.000    0.000    0.000    0.000 datetimes.py:2310(_construct_from_dt64_naive)
#        72    0.000    0.000    0.000    0.000 fromnumeric.py:1126(_argsort_dispatcher)
#        95    0.000    0.000    0.000    0.000 base.py:1671(name)
#        12    0.000    0.000    0.000    0.000 datetimes.py:847(tz_convert)
#        47    0.000    0.000    0.000    0.000 range.py:553(equals)
#        37    0.000    0.000    0.000    0.000 take.py:325(_get_take_nd_function)
#         2    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1156(set_data)
#         5    0.000    0.000    0.001    0.000 _parser.py:979(parse)
#       231    0.000    0.000    0.000    0.000 series.py:1480(_clear_item_cache)
#        17    0.000    0.000    0.000    0.000 series.py:664(_constructor_from_mgr)
#        10    0.000    0.000    0.000    0.000 {method 'argmax' of 'numpy.ndarray' objects}
#    160/19    0.000    0.000    0.001    0.000 <frozen abc>:121(__subclasscheck__)
#        12    0.000    0.000    0.001    0.000 concat.py:357(_is_valid_na_for)
#       108    0.000    0.000    0.000    0.000 base.py:3809(<genexpr>)
#        12    0.000    0.000    0.000    0.000 managers.py:1265(_iset_single)
#        24    0.000    0.000    0.000    0.000 datetimelike.py:2152(unit)
#        12    0.000    0.000    0.019    0.002 accessor.py:95(_getter)
#        28    0.000    0.000    0.000    0.000 fromnumeric.py:1904(ravel)
#        23    0.000    0.000    0.000    0.000 missing.py:466(array_equivalent)
#        12    0.000    0.000    0.003    0.000 arraylike.py:54(__gt__)
#         2    0.000    0.000    0.000    0.000 {built-in method posix.replace}
#        46    0.000    0.000    0.000    0.000 dispatch.py:17(should_extension_dispatch)
#        24    0.000    0.000    0.000    0.000 construction.py:916(<genexpr>)
#        84    0.000    0.000    0.000    0.000 blocks.py:1262(_slice)
#         2    0.000    0.000    0.020    0.010 ops.py:782(result_index)
#         1    0.000    0.000    0.005    0.005 _json.py:923(_get_data_from_filepath)
#        30    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#       184    0.000    0.000    0.000    0.000 multiarray.py:180(concatenate)
#        17    0.000    0.000    0.000    0.000 _compiler.py:243(_optimize_charset)
#        46    0.000    0.000    0.000    0.000 blocks.py:1249(shape)
#        24    0.000    0.000    0.000    0.000 _parser.py:189(__next__)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:179(_get_module_lock)
#         2    0.000    0.000    0.045    0.022 concat.py:157(concat)
#        39    0.000    0.000    0.000    0.000 common.py:131(<lambda>)
#        10    0.000    0.000    0.000    0.000 series.py:1095(__getitem__)
#       120    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         2    0.000    0.000    0.091    0.046 ops.py:758(_get_compressed_codes)
#         2    0.000    0.000    0.000    0.000 {method 'read' of '_io.BufferedReader' objects}
#        28    0.000    0.000    0.000    0.000 common.py:1040(needs_i8_conversion)
#         2    0.000    0.000    0.000    0.000 concat.py:405(__init__)
#        36    0.000    0.000    0.000    0.000 base.py:166(__setattr__)
#       252    0.000    0.000    0.000    0.000 _json.py:1442(<lambda>)
#        15    0.000    0.000    0.000    0.000 cast.py:1760(np_can_hold_element)
#       106    0.000    0.000    0.000    0.000 range.py:376(dtype)
#        13    0.000    0.000    0.000    0.000 multi.py:830(__len__)
#        32    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:126(_path_join)
#        14    0.000    0.000    0.000    0.000 frozen.py:76(__getitem__)
#        12    0.000    0.000    0.000    0.000 missing.py:131(dispatch_fill_zeros)
#         2    0.000    0.000    0.000    0.000 parse.py:374(urlparse)
#         1    0.000    0.000    0.000    0.000 {built-in method posix.listdir}
#        14    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:150(_path_is_mode_type)
#         2    0.000    0.000    0.000    0.000 {method 'write' of '_io.FileIO' objects}
#       150    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#        12    0.000    0.000    0.000    0.000 datetimes.py:281(tz_convert)
#        11    0.000    0.000    0.000    0.000 managers.py:948(from_blocks)
#         1    0.000    0.000    0.004    0.004 _optional.py:85(import_optional_dependency)
#        32    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:128(<listcomp>)
#       113    0.000    0.000    0.000    0.000 enum.py:1257(value)
#        12    0.000    0.000    0.000    0.000 managers.py:2343(make_na_array)
#        36    0.000    0.000    0.000    0.000 locale.py:479(_parse_localename)
#         2    0.000    0.000    0.000    0.000 {built-in method marshal.dumps}
#        37    0.000    0.000    0.000    0.000 construction.py:688(_sanitize_non_ordered)
#        49    0.000    0.000    0.000    0.000 managers.py:913(__init__)
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:132(_path_split)
#         3    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1467(_get_spec)
#        35    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.ndarray' objects}
#        12    0.000    0.000    0.000    0.000 apply.py:121(__init__)
#         3    0.000    0.000    0.000    0.000 grouper.py:527(__init__)
#         6    0.000    0.000    0.000    0.000 algorithms.py:184(_reconstruct_data)
#        28    0.000    0.000    0.000    0.000 numeric.py:1435(<listcomp>)
#         1    0.000    0.000    0.000    0.000 _function_base_impl.py:5272(delete)
#        36    0.000    0.000    0.002    0.000 _strptime.py:564(_strptime_datetime)
#        54    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         5    0.000    0.000    0.002    0.000 _compiler.py:740(compile)
#        12    0.000    0.000    0.000    0.000 datetimes.py:835(_local_timestamps)
#         1    0.000    0.000    0.005    0.005 _json.py:827(__init__)
#        24    0.000    0.000    0.000    0.000 datetimelike.py:2537(dtype_to_unit)
#         4    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#        37    0.000    0.000    0.000    0.000 generic.py:696(ndim)
#        50    0.000    0.000    0.000    0.000 base.py:540(<genexpr>)
#        10    0.000    0.000    0.000    0.000 function.py:124(validate_argmax_with_skipna)
#         1    0.000    0.000    0.000    0.000 common.py:304(_get_filepath_or_buffer)
#        12    0.000    0.000    0.000    0.000 expressions.py:226(evaluate)
#         1    0.000    0.000    0.000    0.000 readers.py:527(validate_integer)
#       3/2    0.000    0.000    0.004    0.002 <frozen importlib._bootstrap>:666(_load_unlocked)
#         3    0.000    0.000    0.000    0.000 generic.py:1826(_check_label_or_level_ambiguity)
#        39    0.000    0.000    0.000    0.000 common.py:126(_classes_and_not_datetimelike)
#        26    0.000    0.000    0.000    0.000 frame.py:4585(_ensure_valid_index)
#         5    0.000    0.000    0.000    0.000 _compiler.py:511(_compile_info)
#         1    0.000    0.000    0.000    0.000 api.py:202(union_indexes)
#        24    0.000    0.000    0.000    0.000 datetimelike.py:2063(_maybe_pin_freq)
#        12    0.000    0.000    0.000    0.000 frame.py:659(_constructor_from_mgr)
#         5    0.000    0.000    0.085    0.017 grouper.py:689(codes)
#         4    0.000    0.000    0.000    0.000 managers.py:557(copy)
#        12    0.000    0.000    0.000    0.000 dataclasses.py:1258(is_dataclass)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:493(_init_module_attrs)
#         1    0.000    0.000    0.000    0.000 <frozen os>:674(__getitem__)
#         1    0.000    0.000    0.000    0.000 parse.py:452(urlsplit)
#        12    0.000    0.000    0.000    0.000 _parser.py:322(weekday)
#        12    0.000    0.000    0.002    0.000 arraylike.py:80(__ror__)
#        24    0.000    0.000    0.000    0.000 common.py:1194(<lambda>)
#        10    0.000    0.000    0.000    0.000 enum.py:1525(__and__)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1127(get_data)
#         9    0.000    0.000    0.000    0.000 concat.py:167(<listcomp>)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:437(cache_from_source)
#         3    0.000    0.000    0.085    0.028 grouper.py:777(_codes_and_uniques)
#         4    0.000    0.000    0.000    0.000 take.py:287(_get_take_nd_function_cached)
#        22    0.000    0.000    0.000    0.000 range.py:280(start)
#        10    0.000    0.000    0.000    0.000 managers.py:984(<listcomp>)
#         2    0.000    0.000    0.004    0.002 common.py:1165(_is_binary_mode)
#        24    0.000    0.000    0.015    0.001 extension.py:67(fget)
#       9/6    0.000    0.000    0.002    0.000 <frozen importlib._bootstrap>:233(_call_with_frames_removed)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:778(spec_from_file_location)
#        12    0.000    0.000    0.177    0.015 _json.py:1505(<lambda>)
#        34    0.000    0.000    0.000    0.000 base.py:791(is_)
#         2    0.000    0.000    0.004    0.002 <frozen importlib._bootstrap_external>:934(exec_module)
#         2    0.000    0.000    0.000    0.000 multi.py:903(_set_levels)
#         2    0.000    0.000    0.000    0.000 concat.py:480(_get_ndims)
#        25    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:140(_path_stat)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1602(_get_spec)
#        12    0.000    0.000    0.000    0.000 nanops.py:543(nanall)
#         7    0.000    0.000    0.001    0.000 missing.py:804(<lambda>)
#         2    0.000    0.000    0.000    0.000 managers.py:708(_slice_take_blocks_ax0)
#        10    0.000    0.000    0.001    0.000 indexing.py:1379(_get_label)
#        63    0.000    0.000    0.000    0.000 _parser.py:256(match)
#        35    0.000    0.000    0.000    0.000 _methods.py:58(_any)
#         2    0.000    0.000    0.000    0.000 base.py:3820(get_indexer)
#        20    0.000    0.000    0.000    0.000 generic.py:4379(_set_is_copy)
#        12    0.000    0.000    0.000    0.000 expressions.py:67(_evaluate_standard)
#         3    0.000    0.000    0.000    0.000 grouper.py:1084(_convert_grouper)
#         1    0.000    0.000    0.000    0.000 base.py:6916(delete)
#        10    0.000    0.000    0.000    0.000 base.py:773(_view)
# ...
#         1    0.000    0.000    0.000    0.000 concat.py:526(_get_empty_dtype)
#         2    0.000    0.000    0.000    0.000 contextlib.py:104(__init__)
#         2    0.000    0.000    0.000    0.000 concat.py:545(_get_sample_object)
#         3    0.000    0.000    0.000    0.000 algorithms.py:217(_ensure_arraylike)
#         5    0.000    0.000    0.000    0.000 groupby.py:1340(<genexpr>)
#         2    0.000    0.000    0.000    0.000 groupby.py:5565(_reindex_output)
#         2    0.000    0.000    0.000    0.000 sorting.py:238(is_int64_overflow_possible)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:748(find_spec)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:599(_check_name_wrapper)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:3328(prod)
#         1    0.000    0.000    0.000    0.000 series.py:5820(dropna)
#         3    0.000    0.000    0.000    0.000 inference.py:105(is_file_like)
#        13    0.000    0.000    0.000    0.000 concat.py:463(<genexpr>)
#         1    0.000    0.000    0.000    0.000 concat.py:751(<listcomp>)
#         3    0.000    0.000    0.001    0.000 _strptime.py:261(compile)
#         1    0.000    0.000    0.000    0.000 api.py:72(get_objs_combined_axis)
#        28    0.000    0.000    0.000    0.000 _function_base_impl.py:5640(_append_dispatcher)
#         1    0.000    0.000    0.000    0.000 api.py:102(<listcomp>)
#        29    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'stream_reader' of 'zstd.ZstdDecompressor' objects}
#         5    0.000    0.000    0.000    0.000 grouper.py:949(<genexpr>)
#        13    0.000    0.000    0.000    0.000 _parser.py:376(_escape)
#         2    0.000    0.000    0.000    0.000 ops.py:696(names)
#         1    0.000    0.000    0.000    0.000 numeric.py:137(ones)
#         2    0.000    0.000    0.000    0.000 managers.py:2320(_preprocess_slice_or_indexer)
#         1    0.000    0.000    0.000    0.000 common.py:131(close)
#         1    0.000    0.000    0.000    0.000 series.py:1087(_slice)
#         2    0.000    0.000    0.000    0.000 contextlib.py:132(__enter__)
#         3    0.000    0.000    0.000    0.000 <frozen _collections_abc>:262(__subclasshook__)
#        13    0.000    0.000    0.000    0.000 _compiler.py:428(_get_iscased)
#        28    0.000    0.000    0.000    0.000 fromnumeric.py:1900(_ravel_dispatcher)
#        18    0.000    0.000    0.000    0.000 {built-in method _imp.release_lock}
#         1    0.000    0.000    0.000    0.000 _validators.py:450(check_dtype_backend)
#         3    0.000    0.000    0.000    0.000 grouper.py:983(is_in_axis)
#        20    0.000    0.000    0.000    0.000 <frozen _collections_abc>:315(__subclasshook__)
#         3    0.000    0.000    0.000    0.000 grouper.py:638(_passed_categorical)
#         1    0.000    0.000    0.000    0.000 concat.py:536(<listcomp>)
#        20    0.000    0.000    0.000    0.000 cast.py:1473(<genexpr>)
#         1    0.000    0.000    0.000    0.000 multi.py:1316(view)
#         5    0.000    0.000    0.000    0.000 _parser.py:963(fix_flags)
#        21    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 multi.py:844(levels)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:405(parent)
#         3    0.000    0.000    0.000    0.000 _parser.py:453(_uniq)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 sorting.py:157(_int64_cut_off)
#        26    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1568(<genexpr>)
#         1    0.000    0.000    0.000    0.000 base.py:1768(_set_names)
#         3    0.000    0.000    0.000    0.000 _virtualenv.py:52(find_spec)
#         2    0.000    0.000    0.000    0.000 contextlib.py:141(__exit__)
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:309(__init__)
#         1    0.000    0.000    0.000    0.000 concat.py:303(<listcomp>)
#         1    0.000    0.000    0.000    0.000 <frozen genericpath>:16(exists)
#         1    0.000    0.000    0.000    0.000 _json.py:1060(close)
#        12    0.000    0.000    0.000    0.000 common.py:686(<lambda>)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1097(__init__)
#         6    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         1    0.000    0.000    0.000    0.000 concat.py:707(_get_comb_axis)
#         6    0.000    0.000    0.000    0.000 _parser.py:304(checkgroupname)
#         1    0.000    0.000    0.000    0.000 base.py:4191(_validate_positional_slice)
#        12    0.000    0.000    0.000    0.000 _parser.py:1056(_could_be_tzname)
#         4    0.000    0.000    0.000    0.000 common.py:535(temp_setattr)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:48(_new_module)
#        16    0.000    0.000    0.000    0.000 multiarray.py:919(bincount)
#        13    0.000    0.000    0.000    0.000 concat.py:754(<genexpr>)
#        12    0.000    0.000    0.000    0.000 base.py:348(_is_boolean)
#         1    0.000    0.000    0.000    0.000 concat.py:777(_concat_indexes)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:180(_path_isabs)
#         2    0.000    0.000    0.000    0.000 base.py:1010(view)
#        14    0.000    0.000    0.000    0.000 _function_base_impl.py:5452(_insert_dispatcher)
#         3    0.000    0.000    0.000    0.000 grouper.py:722(_result_index)
#         6    0.000    0.000    0.000    0.000 _parser.py:98(closegroup)
#         3    0.000    0.000    0.000    0.000 concat.py:73(<listcomp>)
#         3    0.000    0.000    0.000    0.000 multiarray.py:1148(putmask)
#         1    0.000    0.000    0.000    0.000 <string>:2(__init__)
#        16    0.000    0.000    0.000    0.000 common.py:178(<genexpr>)
#        11    0.000    0.000    0.000    0.000 base.py:1176(_maybe_disallow_fill)
#         1    0.000    0.000    0.000    0.000 <frozen os>:1081(__subclasshook__)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1146(path_stats)
#        14    0.000    0.000    0.000    0.000 {function FrozenList.__getitem__ at 0x7f873e7a3920}
#         6    0.000    0.000    0.000    0.000 {method 'to_bytes' of 'int' objects}
#         3    0.000    0.000    0.000    0.000 base.py:782(_rename)
#         1    0.000    0.000    0.000    0.000 {built-in method _codecs.lookup}
#         1    0.000    0.000    0.000    0.000 common.py:641(fill_missing_names)
#         2    0.000    0.000    0.000    0.000 managers.py:586(<listcomp>)
#         1    0.000    0.000    0.000    0.000 base.py:5491(_concat)
#         8    0.000    0.000    0.000    0.000 {method 'extend' of 'bytearray' objects}
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1239(exec_module)
#        12    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#         5    0.000    0.000    0.000    0.000 multi.py:1571(_get_names)
#         1    0.000    0.000    0.000    0.000 api.py:330(_sanitize_and_check)
#        12    0.000    0.000    0.000    0.000 datetimes.py:2484(_maybe_infer_tz)
#        14    0.000    0.000    0.000    0.000 numeric.py:1444(_moveaxis_dispatcher)
#         1    0.000    0.000    0.000    0.000 base.py:6324(_maybe_downcast_for_indexing)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1220(__init__)
#        12    0.000    0.000    0.000    0.000 _compiler.py:31(_combine_flags)
#         1    0.000    0.000    0.000    0.000 indexing.py:1696(_get_list_axis)
#         1    0.000    0.000    0.000    0.000 platform.py:1002(_sys_version)
#         6    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#         2    0.000    0.000    0.000    0.000 <string>:1(<lambda>)
#         2    0.000    0.000    0.000    0.000 base.py:7719(<genexpr>)
#         2    0.000    0.000    0.000    0.000 ops.py:698(<listcomp>)
#         1    0.000    0.000    0.000    0.000 _json.py:907(_preprocess_data)
#         1    0.000    0.000    0.000    0.000 _decorators.py:325(wrapper)
#         2    0.000    0.000    0.000    0.000 concat.py:693(_get_result_dim)
#         1    0.000    0.000    0.000    0.000 selectn.py:63(is_valid_dtype_n_method)
#         3    0.000    0.000    0.000    0.000 groupby.py:5607(<genexpr>)
#         2    0.000    0.000    0.000    0.000 groupby.py:2142(_obj_1d_constructor)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:165(__init__)
#         1    0.000    0.000    0.000    0.000 common.py:1117(_maybe_memory_map)
#         1    0.000    0.000    0.000    0.000 cast.py:524(ensure_dtype_can_hold_na)
#         2    0.000    0.000    0.000    0.000 base.py:3996(_check_indexing_method)
#         5    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 grouper.py:1080(_is_label_like)
#         1    0.000    0.000    0.000    0.000 multi.py:897(<listcomp>)
#         1    0.000    0.000    0.000    0.000 cast.py:1952(np_can_cast_scalar)
#         1    0.000    0.000    0.000    0.000 _optional.py:74(get_version)
#         3    0.000    0.000    0.000    0.000 grouper.py:999(is_in_obj)
#        10    0.000    0.000    0.000    0.000 nanops.py:1431(_maybe_arg_null_out)
#         1    0.000    0.000    0.000    0.000 common.py:86(consensus_name_attr)
#         2    0.000    0.000    0.000    0.000 _compiler.py:398(_simple)
#         3    0.000    0.000    0.000    0.000 generic.py:1847(<genexpr>)
#         6    0.000    0.000    0.000    0.000 {method 'index' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 indexing.py:161(iloc)
#         1    0.000    0.000    0.000    0.000 api.py:351(<setcomp>)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1101(_sanity_check)
#         6    0.000    0.000    0.000    0.000 __init__.py:470(_parse_letter_version)
#         2    0.000    0.000    0.000    0.000 common.py:174(not_none)
#         1    0.000    0.000    0.000    0.000 base.py:5425(_getitem_slice)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         6    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#        12    0.000    0.000    0.000    0.000 _parser.py:186(__iter__)
#         1    0.000    0.000    0.000    0.000 cast.py:921(_maybe_infer_dtype_type)
#         8    0.000    0.000    0.000    0.000 managers.py:1828(ndim)
#         1    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:91(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 common.py:1342(is_complex_dtype)
#         1    0.000    0.000    0.000    0.000 selectn.py:44(__init__)
#         1    0.000    0.000    0.000    0.000 common.py:515(get_compression_method)
#         2    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 __init__.py:149(__lt__)
#         1    0.000    0.000    0.000    0.000 base.py:5486(<setcomp>)
#        10    0.000    0.000    0.000    0.000 multiarray.py:690(result_type)
#         6    0.000    0.000    0.000    0.000 {method 'isidentifier' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 base.py:6685(_validate_indexer)
#         4    0.000    0.000    0.000    0.000 multi.py:1046(nlevels)
#         5    0.000    0.000    0.000    0.000 <frozen _collections_abc>:283(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 indexing.py:2752(need_slice)
#         3    0.000    0.000    0.000    0.000 grouper.py:661(_ilevel)
#         1    0.000    0.000    0.000    0.000 base.py:7718(<listcomp>)
#         1    0.000    0.000    0.000    0.000 generic.py:580(_get_axis_name)
#         1    0.000    0.000    0.000    0.000 sorting.py:170(<listcomp>)
#         2    0.000    0.000    0.000    0.000 base.py:346(shape)
#         1    0.000    0.000    0.000    0.000 getlimits.py:708(min)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:70(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 {built-in method _codecs.lookup_error}
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:71(_relax_case)
#         4    0.000    0.000    0.000    0.000 __init__.py:534(<lambda>)
#         1    0.000    0.000    0.000    0.000 managers.py:2017(_can_hold_na)
#         1    0.000    0.000    0.000    0.000 series.py:702(_can_hold_na)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2018(nonzero)
#         2    0.000    0.000    0.000    0.000 base.py:6679(_maybe_cast_listlike_indexer)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:413(has_location)
#         1    0.000    0.000    0.000    0.000 common.py:657(<listcomp>)
#         1    0.000    0.000    0.000    0.000 getlimits.py:721(max)
#         1    0.000    0.000    0.000    0.000 cast.py:736(_ensure_dtype_type)
#         1    0.000    0.000    0.000    0.000 concat.py:635(<listcomp>)
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:260(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'find' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 base.py:6312(_index_as_unique)
#         1    0.000    0.000    0.000    0.000 <frozen _collections_abc>:362(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 base.py:7723(_unpack_nested_dtype)
#         1    0.000    0.000    0.000    0.000 base.py:5495(<listcomp>)
#         1    0.000    0.000    0.000    0.000 concat.py:724(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {built-in method _imp.exec_dynamic}
#         1    0.000    0.000    0.000    0.000 base.py:6415(_is_comparable_dtype)
#         1    0.000    0.000    0.000    0.000 <frozen _collections_abc>:381(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 managers.py:553(nblocks)
#         2    0.000    0.000    0.000    0.000 _parser.py:172(__setitem__)
#         3    0.000    0.000    0.000    0.000 parse.py:108(_noop)
#         2    0.000    0.000    0.000    0.000 __init__.py:508(_parse_local_version)
#         1    0.000    0.000    0.000    0.000 common.py:1122(<lambda>)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1122(get_filename)
#         1    0.000    0.000    0.000    0.000 parse.py:421(_checknetloc)
#         2    0.000    0.000    0.000    0.000 missing.py:1073(clean_reindex_fill_method)
#         1    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2584(_all_dispatcher)
#         1    0.000    0.000    0.000    0.000 base.py:692(_constructor)
#         1    0.000    0.000    0.000    0.000 concat.py:770(_maybe_check_integrity)
#         1    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:3323(_prod_dispatcher)
#         1    0.000    0.000    0.000    0.000 managers.py:1989(index)
#         1    0.000    0.000    0.000    0.000 {method 'lstrip' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:931(create_module)
#         1    0.000    0.000    0.000    0.000 {method 'pop' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 range.py:231(_constructor)
#         1    0.000    0.000    0.000    0.000 _json.py:1070(__iter__)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2014(_nonzero_dispatcher)
#         1    0.000    0.000    0.000    0.000 _function_base_impl.py:5268(_delete_dispatcher)
#         1    0.000    0.000    0.000    0.000 generic.py:4518(_check_inplace_and_allows_duplicate_labels)
#         1    0.000    0.000    0.000    0.000 base.py:323(_consolidate_inplace)

# %% [markdown]
# Más de la mitad del tiempo de ejecución lo acapara la lectura del archivo JSON, aun cuando se está leyendo por *chunks*. `pandas` es una excelente herramienta, pero para este caso en específico, no es la opción más rápida debido al tiempo que se necesita para leer los datos.
#
# En vez, en la solución `q1_time` optamos por trabajar con arreglos de `numpy`; a cambio de un uso mayor de memoria conseguimos el procesamiento de datos sin tener que iterar con un bucle `for` como en `q1_memory`.
#
# Por completez, validemos que los resultados con `pandas` sean consistentes con los obtenidos por las otras dos funciones.

# %%
print(q1_mem_result == q1_time_result == q1_pandas_result, q1_pandas_result)
# Out:
# True [(datetime.date(2021, 2, 12), 'RanbirS00614606'), (datetime.date(2021, 2, 13), 'MaanDee08215437'), (datetime.date(2021, 2, 17), 'RaaJVinderkaur'), (datetime.date(2021, 2, 16), 'jot__b'), (datetime.date(2021, 2, 14), 'rebelpacifist'), (datetime.date(2021, 2, 18), 'neetuanjle_nitu'), (datetime.date(2021, 2, 15), 'jot__b'), (datetime.date(2021, 2, 20), 'MangalJ23056160'), (datetime.date(2021, 2, 23), 'Surrypuria'), (datetime.date(2021, 2, 19), 'Preetm91')]

# %% [markdown]
# Cabe resaltar que la lectura línea por línea del archivo JSON (o bien *chunk* por *chunk*) se vuelve cada vez menos viable conforme el conjunto de datos crece. En nuestro caso es un archivo JSON relativamente pequeño, pero si tuviéramos que lidiar con un conjunto de datos cuyo volumen estuviera en el orden de GiB o incluso TiB, debemos acudir al procesamiento distribuido. Herramientas como `pyspark` o `apache_beam` serían la solución. Por supuesto, en estos casos tendríamos que aprovisionar un clúster; en GCP, por ejemplo, necesitaríamos usar Dataproc o Dataflow respectivamente.
#
# Para efectos prácticos, corramos `apache_beam` en local sólo para ilustrar el ejemplo. `q3` se presta muy bien para construir un *pipeline* con dicha herramienta.

# %%
from json import loads

from apache_beam import CombinePerKey, Map, Filter, FlatMap, Pipeline
from apache_beam.transforms.combiners import Top
from apache_beam.io import ReadFromText


def run_beam_pipeline():

    with Pipeline() as pipeline:
        _ = (
            pipeline
            | "ReadFromText" >> ReadFromText(FILE_PATH)
            | "ConvertToDict" >> Map(lambda record: loads(record))
            | "FilterNulls" >> Filter(lambda record: record.get("mentionedUsers") is not None)
            | "GetUsers" >> FlatMap(lambda record: record["mentionedUsers"])
            | "GetUsernames" >> Map(lambda record: (record["username"], 1))
            | "CombinePerKey" >> CombinePerKey(sum)
            | "GetTop10" >> Top.Of(10, key=lambda record: record[1])
            | Map(print)  # Here goes your sink, something like WriteToText or WriteToBigQuery
        )

# %%
run_beam_pipeline()
# Out:
# WARNING:apache_beam.runners.interactive.interactive_environment:Dependencies required for Interactive Beam PCollection visualization are not available, please use: `pip install apache-beam[interactive]` to install necessary dependencies to enable all data visualization features.
# WARNING:apache_beam.transforms.core:('No iterator is returned by the process method in %s.', <class 'apache_beam.transforms.combiners._TopPerBundle'>)
# [('narendramodi', 2265), ('Kisanektamorcha', 1840), ('RakeshTikaitBKU', 1644), ('PMOIndia', 1427), ('RahulGandhi', 1146), ('GretaThunberg', 1048), ('RaviSinghKA', 1019), ('rihanna', 986), ('UNHumanRights', 962), ('meenaharris', 926)]

# %% [markdown]
# Nótese en el `stdout` que los resultados son consistentes con `q3_mem_result` y `q3_time_result`, lo cual comprueba que `apache_beam` es también una alternativa para hacer este procesamiento de datos, aunque esta solución sería más apropiada para correr en un ambiente distribuido para atender volúmenes de datos mucho más grandes. `apache_beam` sólo se debe correr en local con propósitos de desarrollo y pruebas.

# %% [markdown]
# ## Conclusiones
# Como conclusiones me gustaría enlistar las siguientes:
# - Los resultados son consistentes entre las funciones que optimizan el uso de memoria y las que optimizan el tiempo de ejecución.
# - Para las funciones que priorizan el bajo uso de memoria se evitó al máximo el uso de librerías externas y se procuró trabajar con las funciones estándar de python.
# - Para las funciones que priorizan el tiempo de ejecución se puso especial enfásis en la lectura del archivo JSON, ya que se identificó que era en esa etapa donde el código toma mayor tiempo. Por lo mismo, se decidió usar la librería `msgspec`, la cual es una alternativa más rápida a la librería estándar `json`. Además, en `q1` se aprovechó el uso de arreglos `numpy` para evitar el uso de bucles al buscar los usuarios más activos.
# - Las soluciones propuestas son específicas para el archivo JSON proporcionado. Con otros conjuntos de datos otras soluciones podrían ser viables tanto en términos de uso de memoria como en tiempos de ejecución, dependiendo del volumen y de la estructura de los datos, entre las cuales se mencionaron `pandas` y `apache_beam`.
# - Procuré codificar de manera tal que el código se explique por sí solo. Dejé algunos comentarios donde lo vi necesario.
